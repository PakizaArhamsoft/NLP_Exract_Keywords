# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.4.0/en_core_sci_lg-0.4.0.tar.gz
import spacy
nlp = spacy.load("en_core_sci_lg")

import yake
kw_extractor = yake.KeywordExtractor()
language = "en"
max_ngram_size = 3
deduplication_threshold = 0.9
numOfKeywords = 20
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)

from rake_nltk import Rake
rake_nltk_var = Rake()

# %pip install summa
from summa import keywords as Skeywords

# %pip install keybert
from keybert import KeyBERT
kw_model = KeyBERT(model='all-mpnet-base-v2')

# %%
texts = [ 
          "Bachelor's Degree from an accredited college or university with a major in Computer Science, Information Systems, Engineering, Business, or other related scientific or technical discipline or three (3) years of equivalent experience in a related field.  A Master's Degree is preferred.",
          "Bachelor's Degree from an accredited college or university in Engineering, Computer Science, Information Systems, Business or other related discipline. Master's degree or project management certification is preferred.",
          "Bachelor's Degree from an accredited college or university with a major in Computer Science, Information Systems, Engineering, Business, or other related scientific or technical discipline or three (3) years of equivalent experience in a related field.  A Master's Degree is preferred.",
          "Bachelor's Degree from an accredited college or university in Engineering, Computer Science, Information Systems, Business, or other related Discipline.  Master's degree preferred.",
          "Bachelor's degree from an accredited college or university in Engineering, Computer Science, Information Systems, Business, or other related discipline.",
          "Bachelor's Degree from an accredited college or university in Engineering, Computer Science, Information Systems, Public Health, or other related discipline. Master's degree and/or project management certification is preferred. PMI-ACP, CSM or equivalent certification.",
          "Bachelor's Degree from an accredited college or university in Business, Human Resources Management or a related field. An MBA or MPA is preferred.",
          "Bachelor's degree or foreign equivalent required from an accredited institution. Will also consider three years of progressive experience in the specialty in lieu of every year of education.",
          "Bachelor's Degree from an accredited college or university in Engineering, Computer Science, Information Systems, Public Health, or other related discipline. Master's degree and/or project management certification is preferred. PMP certification. PMI-ACP, CSM or equivalent certification."
          ]

# %% [markdown]
# Using Spacy NLP

# %%
for text in texts:
    doc = nlp(text)
    print("Query'Keywords: ",doc.ents)
    print('\n')
# Out:
# Query'Keywords:  (Bachelor's, Degree, accredited, college, university, Computer Science, Information Systems, Engineering, Business, scientific, technical discipline, years, equivalent, experience, Master's, Degree)
#
#
# Query'Keywords:  (Bachelor's, Degree, accredited, college, university, Engineering, Computer Science, Information Systems, Business, discipline, Master's, degree, project, management, certification)
#
#
# Query'Keywords:  (Bachelor's, Degree, accredited, college, university, Computer Science, Information Systems, Engineering, Business, scientific, technical discipline, years, equivalent, experience, Master's, Degree)
#
#
# Query'Keywords:  (Bachelor's, Degree, accredited, college, university, Engineering, Computer Science, Information Systems, Business, Discipline, Master's, degree)
#
#
# Query'Keywords:  (Bachelor's, degree, accredited, college, university, Engineering, Computer Science, Information Systems, Business, discipline)
#
#
# Query'Keywords:  (Bachelor's, Degree, accredited, college, university, Engineering, Computer Science, Information Systems, Public Health, discipline, Master's, degree, project, management, certification, PMI-ACP, CSM, certification)
#
#
# Query'Keywords:  (Bachelor's, Degree, accredited, college, university, Business, Human Resources Management, MBA, MPA)
#
#
# Query'Keywords:  (Bachelor's, degree, foreign, equivalent, accredited, institution, years, progressive, experience, specialty, year, education)
#
#
# Query'Keywords:  (Bachelor's, Degree, accredited, college, university, Engineering, Computer Science, Information Systems, Public Health, discipline, Master's, degree, project, management, certification, PMP, certification, PMI-ACP, CSM, certification)

# %% [markdown]
# Using Yake NLP

# %%
# Yet Another Keyword Extractor (Yake) library selects the most important keywords using the text statistical features method 
# from the article. With the help of YAKE, you can control the extracted keyword word count and other features.

# %%
for text in texts:
     keywords = custom_kw_extractor.extract_keywords(text)
     print("Query'Keywords: ")
     for kw in keywords:
          print(kw)
     print('\n')
# Out:
# Query'Keywords:
# ('accredited', 0.2299449545753006)
#
#
# Query'Keywords:
# ('Computer Science', 0.0032610119837787367)
# ('Information Systems', 0.0032610119837787367)
# ('university in Engineering', 0.009108237309423345)
# ('Bachelor degree', 0.015380821171891606)
# ('related discipline', 0.015380821171891606)
# ('accredited college', 0.02570861714399338)
# ('college or university', 0.02570861714399338)
# ('Business', 0.030396371632413578)
# ('Engineering', 0.057012387690331526)
# ('Computer', 0.057012387690331526)
# ('Science', 0.057012387690331526)
# ('Information', 0.057012387690331526)
# ('Systems', 0.057012387690331526)
# ('Bachelor', 0.09568045026443411)
# ('discipline', 0.09568045026443411)
# ('degree', 0.15831692877998726)
# ('accredited', 0.15831692877998726)
# ('college', 0.15831692877998726)
# ('university', 0.15831692877998726)
# ('related', 0.15831692877998726)
#
#
# Query'Keywords:
# ('Computer Science', 0.0035935265869399724)
# ('Information Systems', 0.0035935265869399724)
# ('Public Health', 0.0035935265869399724)
# ('university in Engineering', 0.010067319929807635)
# ('related discipline', 0.020720197448804205)
# ('Bachelor Degree', 0.0268570244235125)
# ('accredited college', 0.028535357329380496)
# ('college or university', 0.028535357329380496)
# ('Engineering', 0.05983861121562959)
# ('Computer', 0.05983861121562959)
# ('Science', 0.05983861121562959)
# ('Information', 0.05983861121562959)
# ('Systems', 0.05983861121562959)
# ('Public', 0.05983861121562959)
# ('Health', 0.05983861121562959)
# ('Master degree', 0.07503674162783322)
# ('Degree', 0.107303227178476)
# ('project management certification', 0.11757826207820964)
# ('Bachelor', 0.12187233622811038)
# ('discipline', 0.12187233622811038)
#
#
# Query'Keywords:
# ('Human Resources Management', 0.0003281199588665549)
# ('Human Resources', 0.004264747658160558)
# ('Resources Management', 0.005842023901156067)
# ('Bachelor Degree', 0.007701730664586866)
# ('university in Business', 0.008334116283452563)
# ('related field', 0.015099935621315529)
# ('accredited college', 0.02249651976012989)
# ('college or university', 0.02249651976012989)
# ('MBA or MPA', 0.0521883172778223)
# ('Business', 0.05572221155747183)
# ('Human', 0.05572221155747183)
# ('MPA is preferred', 0.06627380602544088)
# ('Degree', 0.07621084492189614)
# ('Resources', 0.07621084492189614)
# ('Management', 0.07621084492189614)
# ('Bachelor', 0.10028582371075691)
# ('field', 0.10028582371075691)
# ('accredited', 0.14832923246533666)
# ('college', 0.14832923246533666)
# ('university', 0.14832923246533666)
#
#
# Query'Keywords:
# ('foreign equivalent required', 0.005677237761441965)
# ('Bachelor degree', 0.02098300755978004)
# ('accredited institution', 0.02098300755978004)
# ('degree or foreign', 0.031040804666112243)
# ('foreign equivalent', 0.031040804666112243)
# ('equivalent required', 0.031040804666112243)
# ('Bachelor', 0.11844607236827376)
# ('institution', 0.11844607236827376)
# ('year of education', 0.14436083755756227)
# ('degree', 0.17351161766281323)
# ('foreign', 0.17351161766281323)
# ('equivalent', 0.17351161766281323)
# ('required', 0.17351161766281323)
# ('accredited', 0.17351161766281323)
# ('years of progressive', 0.2007501781785641)
# ('progressive experience', 0.21626281206510953)
# ('specialty in lieu', 0.21626281206510953)
# ('education', 0.31817081130554614)
# ('years', 0.39648436941444604)
# ('year', 0.39648436941444604)
#
#
# Query'Keywords:
# ('Computer Science', 0.004169009623433066)
# ('Information Systems', 0.004169009623433066)
# ('Public Health', 0.004169009623433066)
# ('university in Engineering', 0.012605333517946479)
# ('related discipline', 0.028326713202073046)
# ('Bachelor Degree', 0.03453569539380963)
# ('accredited college', 0.03877239024289151)
# ('college or university', 0.03877239024289151)
# ('Engineering', 0.06443369569891877)
# ('Computer', 0.06443369569891877)
# ('Science', 0.06443369569891877)
# ('Information', 0.06443369569891877)
# ('Systems', 0.06443369569891877)
# ('Public', 0.06443369569891877)
# ('Health', 0.06443369569891877)
# ('Master degree', 0.09375202903443657)
# ('Degree', 0.11706545309830996)
# ('Bachelor', 0.14258176256178778)
# ('discipline', 0.14258176256178778)
# ('PMP certification', 0.15826508245323206)

# %% [markdown]
# Using Rake_nltk NLP

# %%
# You can form a powerful keyword extraction method by combining the Rapid Automatic Keyword Extraction (RAKE) algorithm 
# with the NLTK toolkit.

# %%
for text in texts:
    rake_nltk_var.extract_keywords_from_text(text)
    keyword_extracted = rake_nltk_var.get_ranked_phrases()
    print("Query'Keywords: ",keyword_extracted)
    print('\n')
# Out:
# Query'Keywords:  ['technical discipline', 'related scientific', 'related field', 'information systems', 'equivalent experience', 'computer science', 'accredited college', 'years', 'university', 'three', 'preferred', 'master', 'major', 'engineering', 'degree', 'degree', 'business', 'bachelor', '3']
#
#
# Query'Keywords:  ['project management certification', 'related discipline', 'information systems', 'computer science', 'accredited college', 'university', 'preferred', 'master', 'engineering', 'degree', 'degree', 'business', 'bachelor']
#
#
# Query'Keywords:  ['technical discipline', 'related scientific', 'related field', 'information systems', 'equivalent experience', 'computer science', 'accredited college', 'years', 'university', 'three', 'preferred', 'master', 'major', 'engineering', 'degree', 'degree', 'business', 'bachelor', '3']
#
#
# Query'Keywords:  ['related discipline', 'information systems', 'computer science', 'accredited college', 'degree preferred', 'degree', 'university', 'master', 'engineering', 'business', 'bachelor']
#
#
# Query'Keywords:  ['related discipline', 'information systems', 'computer science', 'accredited college', 'university', 'engineering', 'degree', 'business', 'bachelor']
#
#
# Query'Keywords:  ['project management certification', 'equivalent certification', 'related discipline', 'public health', 'information systems', 'computer science', 'accredited college', 'university', 'preferred', 'pmi', 'master', 'engineering', 'degree', 'degree', 'csm', 'bachelor', 'acp']
#
#
# Query'Keywords:  ['human resources management', 'related field', 'accredited college', 'university', 'preferred', 'mpa', 'mba', 'degree', 'business', 'bachelor']
#
#
# Query'Keywords:  ['also consider three years', 'foreign equivalent required', 'progressive experience', 'every year', 'accredited institution', 'specialty', 'lieu', 'education', 'degree', 'bachelor']
#
#
# Query'Keywords:  ['project management certification', 'pmp certification', 'equivalent certification', 'related discipline', 'public health', 'information systems', 'computer science', 'accredited college', 'university', 'preferred', 'pmi', 'master', 'engineering', 'degree', 'degree', 'csm', 'bachelor', 'acp']

# %% [markdown]
# Using TextRank NLP

# %%
# TextRank is an unsupervised method for extracting keywords and sentences. It is based on a graph where each node is a word, 
# and edges represent relationships between words which are formed by defining the co-occurrence of words within a moving 
# window of a predetermined size.

# %%
for text in texts:
    TR_keywords = Skeywords.keywords(text, scores=True)
    print("Query'Keywords: ",TR_keywords[0:10])
    print('\n')
# Out:
# Query'Keywords:  [('accredited college', 0.7062362183032247)]
#
#
# Query'Keywords:  [('accredited college', 0.7060788754021493)]
#
#
# Query'Keywords:  [('accredited college', 0.7062362183032247)]
#
#
# Query'Keywords:  [('preferred', 0.617594496358518), ('degree', 0.6175944963585178)]
#
#
# Query'Keywords:  [('college', 0.7070828199096467)]
#
#
# Query'Keywords:  [('accredited college', 0.7070697689251593), ('information', 0.005221330786619044)]
#
#
# Query'Keywords:  [('college', 0.7070828199096467)]
#
#
# Query'Keywords:  [('equivalent', 0.8164676848469393)]
#
#
# Query'Keywords:  [('accredited college', 0.7070441503327372), ('discipline', 0.0053793232687609025)]

# %% [markdown]
# Using KeyBert NLP

# %%
# KeyBERT is a simple, easy-to-use keyword extraction algorithm that takes advantage of SBERT embeddings to generate 
# keywords and key phrases from a document that are more similar to the document.

# %%
for text in texts:
    keywords = kw_model.extract_keywords(text, 

                                        keyphrase_ngram_range=(1, 3), 

                                        stop_words='english', 

                                        highlight=False,

                                        top_n=10)

    keywords_list= list(dict(keywords).keys())

    print("Query'Keywords: ",keywords_list)
    print('\n')
# Out:
# Query'Keywords:  ['major computer science', 'master degree preferred', 'university major computer', 'degree preferred', 'information systems engineering', 'computer science', 'computer science information', 'bachelor degree accredited', 'bachelor degree', 'systems engineering business']
#
#
# Query'Keywords:  ['project management certification', 'degree project management', 'management certification preferred', 'management certification', 'engineering computer science', 'certification preferred', 'systems business related', 'master degree', 'university engineering', 'project management']
#
#
# Query'Keywords:  ['major computer science', 'master degree preferred', 'university major computer', 'degree preferred', 'information systems engineering', 'computer science', 'computer science information', 'bachelor degree accredited', 'bachelor degree', 'systems engineering business']
#
#
# Query'Keywords:  ['master degree preferred', 'degree preferred', 'engineering computer science', 'bachelor degree', 'bachelor degree accredited', 'computer science', 'master degree', 'college university engineering', 'engineering computer', 'university engineering computer']
#
#
# Query'Keywords:  ['bachelor degree', 'engineering computer science', 'bachelor degree accredited', 'degree accredited college', 'computer science', 'college university engineering', 'engineering computer', 'degree accredited', 'university engineering computer', 'university engineering']
#
#
# Query'Keywords:  ['project management certification', 'management certification preferred', 'degree project management', 'management certification', 'certification preferred', 'master degree', 'discipline master degree', 'project management', 'master degree project', 'certification preferred pmi']
#
#
# Query'Keywords:  ['business human resources', 'human resources management', 'university business human', 'mba mpa preferred', 'human resources', 'management related field', 'related field mba', 'mba mpa', 'mba', 'field mba']
#
#
# Query'Keywords:  ['required accredited', 'required accredited institution', 'bachelor degree', 'bachelor degree foreign', 'experience specialty', 'equivalent required accredited', 'experience specialty lieu', 'specialty lieu year', 'accredited institution', 'specialty']
#
#
# Query'Keywords:  ['project management certification', 'management certification preferred', 'pmp certification', 'degree project management', 'pmp certification pmi', 'certification pmi', 'management certification', 'preferred pmp certification', 'certification preferred pmp', 'certification pmi acp']
